# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("soil.csv")

# %%
df
# Out:
#      ph  nitrogen  phosphorus  potassium  moisture  organic_carbon soil_health
# 0   6.8        55          42         45        38            0.75        Good
# 1   7.0        50          40         43        35            0.70        Good
# 2   6.5        48          38         40        40            0.65        Good
# 3   5.8        35          30         28        30            0.45    Moderate
# 4   7.8        38          28         32        28            0.40    Moderate
# 5   6.0        32          35         30        25            0.50    Moderate
# 6   4.8        18          15         20        18            0.25        Poor
# 7   8.5        20          18         15        15            0.20        Poor
# 8   5.0        22          20         18        20            0.30        Poor
# 9   7.2        45          35         38        32            0.60        Good
# 10  6.2        40          32         35        30            0.55    Moderate
# 11  8.0        30          25         22        24            0.35    Moderate

# %%
x=df[["ph","nitrogen","phosphorus","potassium","moisture","organic_carbon" ]]
y=df[["soil_health"]]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
rf=Pipeline([

      ("scaler", StandardScaler()),
        ("model",  RandomForestClassifier())

])

# %%
rf_model=rf
rf_model.fit(x,y)
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model', RandomForestClassifier())])

# %%
prediction = rf_model.predict([[8.5,20,18,15,15,0.20]])

print(prediction)
# Out:
# ['Poor']
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import joblib
joblib.dump(rf_model,"soil_health_model.pkl")
# Out:
# ['soil_health_model.pkl']
